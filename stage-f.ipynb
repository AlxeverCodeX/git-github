# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

#import numpy as np # linear algebra
#import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Sav

# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

import seaborn as sns
sns.set(color_codes=True)
sns.set(style='white')

# %%
df_object = pd.read_csv("../input/startup-investments/objects.csv")

# %%
df_object
# Out:
#              id entity_type  entity_id parent_id  \
# 0           c:1     Company          1       NaN
# 1          c:10     Company         10       NaN
# 2         c:100     Company        100       NaN
# 3       c:10000     Company      10000       NaN
# 4       c:10001     Company      10001       NaN
# ...         ...         ...        ...       ...
# 462646   r:9995     Product       9995   c:14164
# 462647   r:9996     Product       9996   c:14164
# 462648   r:9997     Product       9997   c:14164
# 462649   r:9998     Product       9998   c:14164
# 462650   r:9999     Product       9999   c:14164
#
#                                                      name  \
# 0                                                Wetpaint
# 1                                                 Flektor
# 2                                                   There
# 3                                                 MYWEBBO
# 4                                      THE Movie Streamer
# ...

# %%
df_object.describe(include = 'all')
# Out:
#              id entity_type      entity_id parent_id       name  \
# count    462651      462651  462651.000000     27715     462649
# unique   462651           4            NaN     11972     445204
# top     p:28195      Person            NaN    c:2728  Bob Hebig
# freq          1      226708            NaN       152         40
# mean        NaN         NaN  132915.761775       NaN        NaN
# std         NaN         NaN   88768.946816       NaN        NaN
# min         NaN         NaN       1.000000       NaN        NaN
# 25%         NaN         NaN   45249.500000       NaN        NaN
# 50%         NaN         NaN  143072.000000       NaN        NaN
# 75%         NaN         NaN  213868.500000       NaN        NaN
# max         NaN         NaN  286215.000000       NaN        NaN
#
#        normalized_name            permalink category_code     status  \
# count           462620               462651        123186     462651
# ...

# %%
df_object.describe()
# Out:
#            entity_id     logo_width    logo_height  investment_rounds  \
# count  462651.000000  462651.000000  462651.000000      462651.000000
# mean   132915.761775     189.159799     130.488664           0.173939
# std     88768.946816     432.403482     337.191612           3.637983
# min         1.000000       0.000000       0.000000           0.000000
# 25%     45249.500000       0.000000       0.000000           0.000000
# 50%    143072.000000       0.000000       0.000000           0.000000
# 75%    213868.500000     216.000000     139.000000           0.000000
# max    286215.000000   18200.000000    9600.000000         529.000000
#
#        invested_companies  funding_rounds  funding_total_usd     milestones  \
# count       462651.000000   462651.000000       4.626510e+05  462651.000000
# mean             0.138132        0.113749       8.926722e+05       0.265196
# std              2.549245        0.524229       1.700120e+07       0.568577
# ...

# %%
df_object.columns
# Out:
# Index(['id', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
# Printing the Information regarding dataset

print("Info",df_object.info())

# No of rows and columns in Dataset
print('\n\nThe dataset contains {} rows and {} columns'.format(df_object.shape[0],df_object.shape[1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462651 entries, 0 to 462650
# Data columns (total 40 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   462651 non-null  object
#  1   entity_type          462651 non-null  object
#  2   entity_id            462651 non-null  int64
#  3   parent_id            27715 non-null   object
#  4   name                 462649 non-null  object
#  5   normalized_name      462620 non-null  object
#  6   permalink            462651 non-null  object
#  7   category_code        123186 non-null  object
#  8   status               462651 non-null  object
#  9   founded_at           100441 non-null  object
#  10  closed_at            2809 non-null    object
#  11  domain               174942 non-null  object
#  12  homepage_url         174942 non-null  object
#  13  twitter_username     126089 non-null  object
#  14  logo_url             208850 non-null  object
# ...

# %%
# View the datatypes of each feature
df_object.dtypes
# Out:
# id                      object
# entity_type             object
# entity_id                int64
# parent_id               object
# name                    object
# normalized_name         object
# permalink               object
# category_code           object
# status                  object
# founded_at              object
# closed_at               object
# domain                  object
# homepage_url            object
# twitter_username        object
# logo_url                object
# logo_width               int64
# logo_height              int64
# short_description       object
# description             object
# overview                object
# tag_list                object
# country_code            object
# state_code              object
# city                    object
# region                  object
# first_investment_at     object
# last_investment_at      object
# investment_rounds        int64
# invested_companies       int64
# first_funding_at        object
# ...

# %%
# check for missing data in the  data
df_object.isnull().sum()
# Out:
# id                          0
# entity_type                 0
# entity_id                   0
# parent_id              434936
# name                        2
# normalized_name            31
# permalink                   0
# category_code          339465
# status                      0
# founded_at             362210
# closed_at              459842
# domain                 287709
# homepage_url           287709
# twitter_username       336562
# logo_url               253801
# logo_width                  0
# logo_height                 0
# short_description      455034
# description            367646
# overview               227416
# tag_list               356155
# country_code           367608
# state_code             407891
# city                   371967
# region                      0
# first_investment_at    445695
# last_investment_at     445695
# investment_rounds           0
# invested_companies          0
# first_funding_at       431144
# last_funding_at        431144
# ...

# %%
#lets check percentange of missing value
missing_value_train=pd.DataFrame(data=df_object.isnull().sum()/len(df_object)*100,index=df_object.columns,columns=['missing%'])
missing_value_train.sort_values(by='missing%',ascending=False, inplace=True)
missing_value_train[missing_value_train['missing%'] >0]
# Out:
#                       missing%
# closed_at            99.392847
# short_description    98.353619
# last_investment_at   96.335034
# first_investment_at  96.335034
# parent_id            94.009523
# last_funding_at      93.189899
# first_funding_at     93.189899
# state_code           88.163864
# city                 80.399048
# description          79.465083
# country_code         79.456869
# first_milestone_at   78.308055
# last_milestone_at    78.308055
# founded_at           78.290115
# tag_list             76.981353
# category_code        73.373882
# twitter_username     72.746411
# homepage_url         62.187048
# domain               62.187048
# logo_url             54.857982
# overview             49.154979
# created_by           26.621579
# created_at            0.012969
# normalized_name       0.006701
# name                  0.000432

# %%
df_object.drop('closed_at',axis=1,inplace=True)

# %%
df_object.drop('short_description',axis=1,inplace=True)

# %%
df_object.drop('last_investment_at',axis=1,inplace=True)

# %%
df_object.drop('first_investment_at',axis=1,inplace=True)

# %%
df_object.drop('parent_id',axis=1,inplace=True)

# %%
df_object.drop('last_funding_at',axis=1,inplace=True)

# %%
df_object.drop('state_code',axis=1,inplace=True)

# %%
df_object.drop('city',axis=1,inplace=True)

# %%
df_object.drop('description',axis=1,inplace=True)

# %%
df_object.drop('country_code',axis=1,inplace=True)

# %%
df_object.drop('first_milestone_at',axis=1,inplace=True)

# %%
df_object.drop('last_milestone_at',axis=1,inplace=True)

# %%
df_object.drop('founded_at',axis=1,inplace=True)

# %%
df_object.drop('tag_list',axis=1,inplace=True)

# %%
df_object.drop('category_code',axis=1,inplace=True)

# %%
df_object.drop('twitter_username',axis=1,inplace=True)

# %%
df_object.drop('homepage_url',axis=1,inplace=True)

# %%
df_object.drop('domain',axis=1,inplace=True)

# %%
df_object.drop('logo_url',axis=1,inplace=True)

# %%
df_object.drop('overview',axis=1,inplace=True)

# %%
df_object
# Out:
#              id entity_type  entity_id  \
# 0           c:1     Company          1
# 1          c:10     Company         10
# 2         c:100     Company        100
# 3       c:10000     Company      10000
# 4       c:10001     Company      10001
# ...         ...         ...        ...
# 462646   r:9995     Product       9995
# 462647   r:9996     Product       9996
# 462648   r:9997     Product       9997
# 462649   r:9998     Product       9998
# 462650   r:9999     Product       9999
#
#                                                      name  \
# 0                                                Wetpaint
# 1                                                 Flektor
# 2                                                   There
# 3                                                 MYWEBBO
# 4                                      THE Movie Streamer
# ...                                                   ...
# 462646              SiteLink, listing feed for Brokerages
# ...

# %%
df_object.drop('first_funding_at',axis=1,inplace=True)

# %%
df_object
# Out:
#              id entity_type  entity_id  \
# 0           c:1     Company          1
# 1          c:10     Company         10
# 2         c:100     Company        100
# 3       c:10000     Company      10000
# 4       c:10001     Company      10001
# ...         ...         ...        ...
# 462646   r:9995     Product       9995
# 462647   r:9996     Product       9996
# 462648   r:9997     Product       9997
# 462649   r:9998     Product       9998
# 462650   r:9999     Product       9999
#
#                                                      name  \
# 0                                                Wetpaint
# 1                                                 Flektor
# 2                                                   There
# 3                                                 MYWEBBO
# 4                                      THE Movie Streamer
# ...                                                   ...
# 462646              SiteLink, listing feed for Brokerages
# ...

# %%
sns.heatmap(df_object.isnull(),yticklabels=False,cbar=False)

# %%
#to drop any more missing values
df_object.dropna(inplace=True)

# %%
sns.heatmap(df_object.isnull(),yticklabels=False,cbar=False)

# %%
df_object
# Out:
#               id entity_type  entity_id                           name  \
# 0            c:1     Company          1                       Wetpaint
# 1           c:10     Company         10                        Flektor
# 2          c:100     Company        100                          There
# 9       c:100062     Company     100062  Vetter Idea Management System
# 13        c:1001     Company       1001                     FriendFeed
# ...          ...         ...        ...                            ...
# 434907   p:99994      Person      99994                    Kiran Manda
# 434908   p:99995      Person      99995                      Sue Gench
# 434909   p:99996      Person      99996                Rick Tamberrino
# 434910   p:99997      Person      99997                  Peter Lalonde
# 434911   p:99998      Person      99998                   Adam Neumann
#
#                       normalized_name                               permalink  \
# ...

# %%
missing_value_train=pd.DataFrame(data=df_object.isnull().sum()/len(df_object)*100,index=df_object.columns,columns=['missing%'])
missing_value_train.sort_values(by='missing%',ascending=False, inplace=True)
missing_value_train[missing_value_train['missing%'] >0]
# Out:
# Empty DataFrame
# Columns: [missing%]
# Index: []

# %%
df_object.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 339407 entries, 0 to 434911
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  339407 non-null  object
#  1   entity_type         339407 non-null  object
#  2   entity_id           339407 non-null  int64
#  3   name                339407 non-null  object
#  4   normalized_name     339407 non-null  object
#  5   permalink           339407 non-null  object
#  6   status              339407 non-null  object
#  7   logo_width          339407 non-null  int64
#  8   logo_height         339407 non-null  int64
#  9   region              339407 non-null  object
#  10  investment_rounds   339407 non-null  int64
#  11  invested_companies  339407 non-null  int64
#  12  funding_rounds      339407 non-null  int64
#  13  funding_total_usd   339407 non-null  float64
#  14  milestones          339407 non-null  int64
# ...

# %%
sns.countplot(x='name',data=df_object)

# %%
#i could not finish because of the ram on kaggle
